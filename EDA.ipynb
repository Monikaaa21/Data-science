# %%
import numpy as np
import pandas as pd
df=pd.read_csv('Cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.isnull().sum().sum()
# Out:
# np.int64(167)

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
d=np.round(df.mean(),1)
df=df.fillna(d)
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343168     0.003189     0.009894     0.004391     0.001895
# std      11.214329     0.004381     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001572     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000002     0.000173    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
print(df.dtypes)
#no data correction is required(all are float data types)
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
import matplotlib.pyplot as plt
df.boxplot(vert=False)
# Out:
# <Axes: >

# %%
def outlier_capping(df,column):
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)
    IQR=Q3-Q1
    Lower_Extreme=Q1-1.5*IQR
    Upper_Extreme=Q3+1.5*IQR
    df[column]=df[column].apply(lambda x: Lower_Extreme if x<Lower_Extreme else Upper_Extreme if x>Upper_Extreme else x)
for col in df.select_dtypes(['int','float']).columns: 
    outlier_capping(df,col)

# %%
df.boxplot(vert=False)
plt.show()

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.293294     0.003117     0.001568     0.004362     0.001770
# std       9.930226     0.003838     0.002485     0.003001     0.002668
# min     105.000000    -0.008409    -0.003850    -0.005177    -0.004934
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001572     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     161.000000     0.014015     0.006416     0.013564     0.008224
#
#            DS      DP         ASTV         MSTV         ALTV         MLTV  \
# count  2126.0  2126.0  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.0     0.0    46.981873     1.304644     6.691678     8.016361
# std       0.0     0.0    17.612745     0.781091    10.378400     5.046793
# ...

# %%
right skewed with high variability

# %%
import matplotlib.pyplot as plt
plt.hist(df)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df,vert=False)
plt.show()

# %%
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.scatter(df['LB'],df['AC'])
plt.show()

# %%
df.corr()
# Out:
#                 LB        AC        FM        UC        DL  DS  DP      ASTV  \
# LB        1.000000 -0.080638 -0.006907 -0.162778 -0.156229 NaN NaN  0.285623
# AC       -0.080638  1.000000  0.075048  0.093091 -0.103211 NaN NaN -0.272014
# FM       -0.006907  0.075048  1.000000 -0.317265 -0.017610 NaN NaN  0.156351
# UC       -0.162778  0.093091 -0.317265  1.000000  0.268605 NaN NaN -0.215984
# DL       -0.156229 -0.103211 -0.017610  0.268605  1.000000 NaN NaN -0.111624
# DS             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# DP             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# ASTV      0.285623 -0.272014  0.156351 -0.215984 -0.111624 NaN NaN  1.000000
# MSTV     -0.295500  0.214916  0.070300  0.297843  0.566340 NaN NaN -0.433844
# ALTV      0.322330 -0.405709 -0.013420 -0.293340 -0.295886 NaN NaN  0.439040
# MLTV     -0.042615 -0.152296 -0.036872 -0.073998 -0.242552 NaN NaN -0.324728
# ...

# %%
'''from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df[['DS','DP','NSP']]=LE.fit_transform(df[['DS','DP','NSP']])
df.head()'''
# Out:
# "from sklearn.preprocessing import LabelEncoder\nLE=LabelEncoder()\ndf[['DS','DP','NSP']]=LE.fit_transform(df[['DS','DP','NSP']])\ndf.head()"

# %%
import seaborn as sns
dataplot = sns.heatmap(df.corr(numeric_only=True))
plt.show()

# %%
df.corr()
# Out:
#                 LB        AC        FM        UC        DL  DS  DP      ASTV  \
# LB        1.000000 -0.080638 -0.006907 -0.162778 -0.156229 NaN NaN  0.285623
# AC       -0.080638  1.000000  0.075048  0.093091 -0.103211 NaN NaN -0.272014
# FM       -0.006907  0.075048  1.000000 -0.317265 -0.017610 NaN NaN  0.156351
# UC       -0.162778  0.093091 -0.317265  1.000000  0.268605 NaN NaN -0.215984
# DL       -0.156229 -0.103211 -0.017610  0.268605  1.000000 NaN NaN -0.111624
# DS             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# DP             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# ASTV      0.285623 -0.272014  0.156351 -0.215984 -0.111624 NaN NaN  1.000000
# MSTV     -0.295500  0.214916  0.070300  0.297843  0.566340 NaN NaN -0.433844
# ALTV      0.322330 -0.405709 -0.013420 -0.293340 -0.295886 NaN NaN  0.439040
# MLTV     -0.042615 -0.152296 -0.036872 -0.073998 -0.242552 NaN NaN -0.324728
# ...

# %%
df=df.drop(columns=['DS','DP','NSP'])
df
# Out:
#               LB        AC        FM        UC        DL  ASTV  MSTV  ALTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  73.0   0.5  27.5
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  17.0   2.1   0.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  16.0   2.1   0.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  16.0   2.4   0.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  16.0   2.4   0.0
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 2121  140.000000  0.000000  0.006416  0.007426  0.000000  79.0   0.2  25.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  78.0   0.4  22.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  79.0   0.4  20.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  78.0   0.4  27.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  74.0   0.4  27.5
#
#       MLTV  Width  Tendency
# 0      2.4   64.0  0.999926
# ...

# %%
df.corr()
# Out:
#                 LB        AC        FM        UC        DL      ASTV  \
# LB        1.000000 -0.080638 -0.006907 -0.162778 -0.156229  0.285623
# AC       -0.080638  1.000000  0.075048  0.093091 -0.103211 -0.272014
# FM       -0.006907  0.075048  1.000000 -0.317265 -0.017610  0.156351
# UC       -0.162778  0.093091 -0.317265  1.000000  0.268605 -0.215984
# DL       -0.156229 -0.103211 -0.017610  0.268605  1.000000 -0.111624
# ASTV      0.285623 -0.272014  0.156351 -0.215984 -0.111624  1.000000
# MSTV     -0.295500  0.214916  0.070300  0.297843  0.566340 -0.433844
# ALTV      0.322330 -0.405709 -0.013420 -0.293340 -0.295886  0.439040
# MLTV     -0.042615 -0.152296 -0.036872 -0.073998 -0.242552 -0.324728
# Width    -0.140044  0.282866  0.164647  0.131801  0.514648 -0.241131
# Tendency  0.281010  0.029519  0.000961 -0.073728  0.014941 -0.009788
#
#               MSTV      ALTV      MLTV     Width  Tendency
# LB       -0.295500  0.322330 -0.042615 -0.140044  0.281010
# ...

# %%
Variables show moderate to weak linear correlations, suggesting some non-linear relationships that machine learning models could capture better.
The dataset doesn’t include explicit timestamps, so no direct temporal trend can be analyzed.

# %%
Key Insights
ASTV, ALTV, and AC are the most influential indicators of fetal state (NSP).
Positive correlations (ASTV, ALTV, DP) reflect increased fetal distress.
Negative correlations (AC, UC) suggest better fetal health.
Some variables (e.g., ALTV, Width) show high dispersion and skewness, indicating variability in fetal monitoring readings.

# %%
Implications for Decision-Making
These findings can help prioritize clinical monitoring parameters:
Focus on ASTV and ALTV for early warning of fetal distress.
Track AC to confirm healthy conditions.
The insights can support predictive modeling to automatically classify fetal states (normal, suspicious, pathological).
Future work could explore time-series modeling if sequential data becomes available.
